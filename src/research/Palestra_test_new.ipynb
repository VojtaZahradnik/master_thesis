# %%
import random
import sys
sys.path.insert(0,'/home/zahradnik/PycharmProjects/master_thesis')

# %%
from src.modules import conf, fit, df_columns, evl, preprocess
import pandas as pd
import warnings
import matplotlib.pyplot as plt
import numpy as np
import haversine as hs
from gpx_converter import Converter
from datetime import datetime
from xgboost import XGBRFRegressor, XGBRegressor
import statsmodels.api as sm
warnings.simplefilter("ignore")
# Out:
# /home/zahradnik/PycharmProjects/master_thesis/src/modules/__init__.py
# /home/zahradnik/PycharmProjects/master_thesis

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = [24, 8]
plt.rcParams['figure.dpi']
# Out:
# 100.0

# %%
# race_day = datetime.strptime('2022-10-08-10-30', '%Y-%m-%d-%H-%M') # Hradec
race_day = datetime.strptime('2023-03-26-12-00', '%Y-%m-%d-%H-%M') # PALESTRA

# %%
data = fit.load_pcls(
        athlete_name='zahradnik',
        activity_type='running',
        path_to_load=conf["Paths"]["pcl"],
    )
# Out:
# 100%|██████████| 377/377 [00:01<00:00, 359.88it/s]

# %%
data.to_csv("train.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 data.to_csv("train.csv")
#
# AttributeError: 'list' object has no attribute 'to_csv'

# %%
low_dist = []
high_dist = []
for act in data:
    if np.max(act.distance) > 10000:
        high_dist.append(act)
    else:
        low_dist.append(act)
len(low_dist),len(high_dist)
# Out:
# (125, 252)

# %%
train_df = fit.clean_data(pd.concat(data))
len(train_df)
# Out:
# 1028397

# %%
speed_train = train_df.enhanced_speed
heart_train = train_df.heart_rate
cad_train = train_df.cadence

train_df.drop("enhanced_speed",axis=1,inplace=True)
train_df.drop("heart_rate",axis=1,inplace=True)
train_df.drop("cadence",axis=1,inplace=True)

# %%
df = Converter(input_file='hradec_mapy.gpx').gpx_to_dataframe()
df['enhanced_altitude'] = df.altitude
df.drop("altitude",axis=1,inplace=True)

# %%
def calc_dist(pos1: tuple,pos2: tuple) -> int:
    return hs.haversine(pos1, pos2, unit=hs.Unit.METERS)

# %%
## DISTANCE
df['dist_diff'] = [0] + [calc_dist(
    (df['latitude'].iloc[x], df['longitude'].iloc[x]),
    (df['latitude'].iloc[x+1], df['longitude'].iloc[x+1])) for x in range(len(df)-1)]

df['distance'] = df['dist_diff'].cumsum()

# %%
np.max(df.distance)
# Out:
# 21062.858815659685

# %%
df["temp"], df["humidity"], df["rain"], df["snow"], df["wind_speed"] = preprocess.get_meteo(
    df.latitude.iloc[0],
    df.longitude.iloc[0],
    df.enhanced_altitude.iloc[0],
    datetime.strptime('2023-03-26-12-00', '%Y-%m-%d-%H-%M')
)
df.drop(['latitude','longitude'],axis=1,inplace=True)

# %%
df["slope_ascent"], df["slope_descent"] = preprocess.calc_ascent_descent(df)

df["slope_steep"] = preprocess.calc_slope_steep(df)

# %%
df["enhanced_altitude_delayed"] = preprocess.calc_delayed(df.enhanced_altitude, window=1)

# %%
df['hr_zone'] = 5
# df.set_index(["time"], inplace=True)

# %%
test_df= df

# %%
#test_df = preprocess.calc_dt(test_df, cols=['month','week','hour','minute','second'],date=race_day)

# %%
len(train_df.columns),len(test_df.columns)
# Out:
# (124, 13)

# %%
test_df= preprocess.calc_windows(df=test_df,
          lagged=3,
          cols=["slope_steep", "slope_ascent", "slope_descent"])

# %%
len(train_df[test_df.columns].columns),len(test_df.columns)
# Out:
# (19, 19)

# %% [markdown]
# # Cadence

# %%
from sklearn.linear_model import Ridge, LinearRegression, RidgeCV, ElasticNetCV, LassoCV
clf = XGBRegressor()
percent_delay = int(len(test_df) * 0.02)  ## 2% delay
clf.fit(train_df[test_df.columns], cad_train)
y_pred_cad = clf.predict(test_df)
#y_pred_cad = [x if 85 < x < 100 else y_pred_cad.mean() for x in y_pred_cad]

# %%
train_df['cadence'] = cad_train
test_df['cadence'] = y_pred_cad
len(train_df.columns),len(test_df.columns)
# Out:
# (125, 20)

# %%
np.mean(y_pred_cad)
# Out:
# 92.57197

# %%
test_df= preprocess.calc_windows(df=test_df,
          lagged=3,
          cols=["cadence"])
# test_df = preprocess.calc_moving(df=test_df, max_range=110, col="cadence")

# %% [markdown]
# # Heart Rate

# %%
clf = XGBRegressor()
percent_delay = int(len(test_df) * 0.02)  ## 2% delay
clf.fit(train_df[test_df.columns], heart_train)
y_pred_hr = clf.predict(test_df)

# %%
np.mean(y_pred_hr)
# Out:
# 175.74287

# %%
train_df['heart_rate'] = heart_train
test_df['heart_rate'] = y_pred_hr
len(train_df.columns),len(test_df.columns)
# Out:
# (126, 23)

# %%
test_df= preprocess.calc_windows(df=test_df,
          lagged=3,
          cols=["heart_rate"])
#test_df = preprocess.calc_moving(df=test_df, max_range=110, col="heart_rate")

# %%
clf = XGBRegressor()
percent_delay = int(len(test_df) * 0.02)  ## 2% delay
clf.fit(train_df[test_df.columns], speed_train)
y_pred_ridge = clf.predict(test_df)

# %%
_, _ = evl.plot(df=test_df[percent_delay:],pred=test_df['cadence'][percent_delay:],endog = "cadence")

# %%
_, _ = evl.plot(df=test_df[percent_delay:],pred=test_df['heart_rate'][percent_delay:],endog = "heart_rate")

# %%
_, _ = evl.plot(df=test_df[percent_delay:],pred=y_pred_ridge[percent_delay:],endog = "enhanced_speed")

# %%
np.mean(test_df.cadence), np.mean(test_df.heart_rate)
# Out:
# (92.57197, 175.74287)

# %%
y_pred_ridge = [x if x > 15 else np.mean(y_pred_ridge) or x if x < 30 else np.mean(y_pred_ridge) for x in y_pred_ridge]

# %%
import math

# np.mean(speed_test), np.mean(y_pred_ridge), max(test_df.distance)
time = ((np.max(test_df.distance) / 1000) / np.mean(y_pred_ridge)) * 60
minutes = math.floor(time)
seconds = round((time - minutes) * 60)
if seconds == 60:
    seconds=0
    minutes+=1
f'Final time: {minutes}:{seconds}'
# Out:
# 'Final time: 71:28'

# %%
df_map = Converter(input_file='kbely_mapy.gpx').gpx_to_dataframe()
lons = df_map.longitude
lats = df_map.latitude
speed = y_pred_ridge

plt.figure(figsize = (14, 12))
plt.title('Athlete Speed')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.scatter(lons, lats, c = speed)
cbar = plt.colorbar()
cbar.set_label('Speed')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/PycharmProjects/master_thesis/venv/lib/python3.10/site-packages/matplotlib/axes/_axes.py:4220, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4219 try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4220     colors = mcolors.to_rgba_array(c)
#    4221 except (TypeError, ValueError) as err:
#
# File ~/PycharmProjects/master_thesis/venv/lib/python3.10/site-packages/matplotlib/colors.py:377, in to_rgba_array(c, alpha)
#     376 else:
# --> 377     rgba = np.array([to_rgba(cc) for cc in c])
#     379 if alpha is not None:
#
# File ~/PycharmProjects/master_thesis/venv/lib/python3.10/site-packages/matplotlib/colors.py:377, in <listcomp>(.0)
#     376 else:
# --> 377     rgba = np.array([to_rgba(cc) for cc in c])
#     379 if alpha is not None:
#
# File ~/PycharmProjects/master_thesis/venv/lib/python3.10/site-packages/matplotlib/colors.py:187, in to_rgba(c, alpha)
#     186 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 187     rgba = _to_rgba_no_colorcycle(c, alpha)
#     188     try:
#
# File ~/PycharmProjects/master_thesis/venv/lib/python3.10/site-packages/matplotlib/colors.py:269, in _to_rgba_no_colorcycle(c, alpha)
#     268 if not np.iterable(c):
# --> 269     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     270 if len(c) not in [3, 4]:
#
# ValueError: Invalid RGBA argument: 16.62842559814453
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In [371], line 10
#       8 plt.xlabel('Longitude')
#       9 plt.ylabel('Latitude')
# ---> 10 plt.scatter(lons, lats, c = speed)
#      11 cbar = plt.colorbar()
#      12 cbar.set_label('Speed')
#
# File ~/PycharmProjects/master_thesis/venv/lib/python3.10/site-packages/matplotlib/pyplot.py:2817, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2812 @_copy_docstring_and_deprecators(Axes.scatter)
#    2813 def scatter(
#    2814         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2815         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2816         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2817     __ret = gca().scatter(
#    2818         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2819         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2820         edgecolors=edgecolors, plotnonfinite=plotnonfinite,
#    2821         **({"data": data} if data is not None else {}), **kwargs)
#    2822     sci(__ret)
#    2823     return __ret
#
# File ~/PycharmProjects/master_thesis/venv/lib/python3.10/site-packages/matplotlib/__init__.py:1414, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1411 @functools.wraps(func)
#    1412 def inner(ax, *args, data=None, **kwargs):
#    1413     if data is None:
# -> 1414         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1416     bound = new_sig.bind(ax, *args, **kwargs)
#    1417     auto_label = (bound.arguments.get(label_namer)
#    1418                   or bound.kwargs.get(label_namer))
#
# File ~/PycharmProjects/master_thesis/venv/lib/python3.10/site-packages/matplotlib/axes/_axes.py:4386, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4383 if edgecolors is None:
#    4384     orig_edgecolor = kwargs.get('edgecolor', None)
#    4385 c, colors, edgecolors = \
# -> 4386     self._parse_scatter_color_args(
#    4387         c, edgecolors, kwargs, x.size,
#    4388         get_next_color_func=self._get_patches_for_fill.get_next_color)
#    4390 if plotnonfinite and colors is None:
#    4391     c = np.ma.masked_invalid(c)
#
# File ~/PycharmProjects/master_thesis/venv/lib/python3.10/site-packages/matplotlib/axes/_axes.py:4226, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4224 else:
#    4225     if not valid_shape:
# -> 4226         raise invalid_shape_exception(c.size, xsize) from err
#    4227     # Both the mapping *and* the RGBA conversion failed: pretty
#    4228     # severe failure => one may appreciate a verbose feedback.
#    4229     raise ValueError(
#    4230         f"'c' argument must be a color, a sequence of colors, "
#    4231         f"or a sequence of numbers, not {c}") from err
#
# ValueError: 'c' argument has 480 elements, which is inconsistent with 'x' and 'y' with size 337.

# %%
import folium
from branca.element import Figure
from folium import plugins
fig5=Figure(height=550,width=750)
map=folium.Map(location=[df_map.latitude[0], df_map.longitude[0]],tiles='cartodbpositron',zoom_start=14)
fig5.add_child(map)

coords = [[x,y] for x,y in zip(df_map.latitude, df_map.longitude)]
f1=folium.FeatureGroup("Athlete")
line_1=folium.vector_layers.PolyLine(coords,popup='<b>Path of the athlete/b>',tooltip='Athlete',color='blue',weight=10).add_to(f1)
f1.add_to(map)
folium.LayerControl().add_to(map)

map

# %%
max = 255/np.max(y_pred_ridge)
speed = [int(max * x) for x in y_pred_ridge]

def rgb_to_hex(rgb):
    return '%02x%02x%02x' % rgb

# %%
my_map=folium.Map(location=[df_map.latitude[0], df_map.longitude[0]],tiles='cartodbpositron',zoom_start=14)


# for lat,long in zip(df_map.latitude, df_map.longitude):
#     folium.Marker([lat, long], tooltip="Kbely").add_to(my_map)

for x, sped in zip(range(len(coords)),speed):
    folium.PolyLine(
        coords[x:x+2],
        color=f"#{rgb_to_hex((sped,50,100))}",
        weight=10
    ).add_to(my_map)

my_map

# %%
hex(int(y_pred_ridge[32]))
